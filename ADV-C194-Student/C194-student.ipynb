# %%
print("Name :")
print("We will learn about bubble plot today and find some intresting facts about prodution of movies their revenue")
# Out:
# Name :
# We will learn about bubble plot today and find some intresting facts about prodution of movies their revenue

# %% [markdown]
# # Activity 1 - Which movies has collected more than Four hundred million dollors in box office

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

disney_movies = pd.read_csv('disney_movies.csv')
disney_movies
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 1       84300000                2188229052
# 2       83320000                2187090808
# 3       65000000                1078510579
# 4       85000000                 920608730
# ..           ...                       ...
# 574     12545979                  12545979
# 575      8874389                   8874389
# 576    232532923                 232532923
# 577    246082029                 246082029
# 578    529483936                 529483936
#
# [579 rows x 6 columns]

# %%
#Find list of movies who has collected more then Four hundred million dollors in box office
movies_collection = disney_movies.loc[disney_movies['total_gross'] > 400000000]
movies_collection
# Out:
#                               movie_title release_date      genre mpaa_rating  \
# 179                         The Lion King   1994-06-15  Adventure           G
# 441  Pirates of the Caribbean: Dead Man’…   2006-07-07  Adventure       PG-13
# 499                           Toy Story 3   2010-06-18  Adventure           G
# 524                          The Avengers   2012-05-04     Action       PG-13
# 532                            Iron Man 3   2013-05-03     Action       PG-13
# 539                                Frozen   2013-11-22  Adventure          PG
# 558               Avengers: Age of Ultron   2015-05-01     Action       PG-13
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure       PG-13
# 569            Captain America: Civil War   2016-05-06     Action       PG-13
# 571                          Finding Dory   2016-06-17  Adventure          PG
# 578          Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 179    422780140                 761640898
# 441    423315812                 544817142
# 499    415004880                 443408255
# 524    623279547                 660081224
# 532    408992272                 424084233
# 539    400738009                 414997174
# 558    459005868                 459005868
# 564    936662225                 936662225
# 569    408084349                 408084349
# 571    486295561                 486295561
# 578    529483936                 529483936

# %%
#Plot a bubble graph to show which movies who has collected more then Four hundred million dollors in box office
plt.figure(figsize=(12, 8))
plt.xticks(rotation='vertical')

rgb = np.random.rand(3)
print(rgb)

plt.scatter(movies_collection['movie_title'], movies_collection['total_gross'], 
                  c=[rgb],label = 'Total Gross', 
                 alpha=0.5,
                 s = movies_collection['total_gross']/1000000)

plt.legend()
plt.xlabel("Movies", size=14)
plt.ylabel("Total Gross", size=14)
# Out:
# [0.64260553 0.21372954 0.68945939]
# Text(0, 0.5, 'Total Gross')

# %% [markdown]
# Conclusion - Star wars Ep 7: The Force Awakers and The Avengers are 2 movies which made the most in box office till now

# %% [markdown]
# # Activity 2 - Find the total number of movies per year and plot a bubble chart, to find out in which year the maximum  movies were produced

# %%
#Import libraries and read csv 'movie_update.csv'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

movie_update_csv = pd.read_csv("movie_update.csv")
movie_update_csv
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 87%        1     0            0        0     0
# 1                 87%        1     0            0        0     0
# 2                 84%        1     0            0        0     0
# 3                 96%        1     0            0        0     0
# 4                 97%        1     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16739             NaN        0     0            0        1     0
# 16740             NaN        0     0            0        1     0
# 16741             NaN        0     0            0        1     0
# 16742             NaN        0     0            0        1     0
# 16743             NaN        0     0            0        1     0
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1      Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2             Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                     Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                        Sergio Leone                           Western
# ...                               ...                               ...
# 16739                    Bruce Bilson      Comedy,Family,Fantasy,Horror
# 16740                     Neal Israel              Comedy,Family,Sci-Fi
# 16741                    Neil Gelinas                       Documentary
# 16742            Richard Slater-Jones                       Documentary
# 16743                     James Algar          Documentary,Short,Family
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16739                 United States                  English    120.0
# 16740                 United States                  English     90.0
# 16741                 United States                  English      NaN
# 16742                 United States                  English      NaN
# 16743                 United States                  English     32.0
#
# [16744 rows x 17 columns]

# %%
#Group by year column and find total number of movies released each year
group_year = movie_update_csv.groupby("Year")["Title"].count().reset_index()
group_year
# Out:
#      Year  Title
# 0    1902      1
# 1    1912      1
# 2    1913      2
# 3    1915      4
# 4    1916      1
# ..    ...    ...
# 104  2016   1206
# 105  2017   1401
# 106  2018   1285
# 107  2019    689
# 108  2020    147
#
# [109 rows x 2 columns]

# %%
#Plot a bubble graph to show total number of movies released each year
plt.figure(figsize=(20, 8))

plt.scatter(group_year["Year"], group_year["Title"], c="green", label="Number of moives", alpha=0.5, s=group_year["Title"]*3)
plt.xticks(rotation="vertical")
plt.legend()
plt.xlabel("Year", size=14)
plt.ylabel("Number of moives", size=14)
# Out:
# Text(0, 0.5, 'Number of moives')

# %% [markdown]
# Conclusion -

# %% [markdown]
# # Activity 3 - Find which category of movie has the maximum income as per you.

# %%
#Read 'disney_movies.csv'
df = pd.read_csv("disney_movies.csv")
df
#Put a condition as per you to find out which category of movie has the maximum income
moives = df.loc[df["total_gross"] > 300000000]
moives
# Out:
#                                 movie_title release_date      genre  \
# 179                           The Lion King   1994-06-15  Adventure
# 384                            Finding Nemo   2003-05-30  Adventure
# 385  Pirates of the Caribbean: The Curse o…   2003-07-09  Adventure
# 441    Pirates of the Caribbean: Dead Man’…   2006-07-07  Adventure
# 457    Pirates of the Caribbean: At World’…   2007-05-24  Adventure
# 494                     Alice in Wonderland   2010-03-05  Adventure
# 499                             Toy Story 3   2010-06-18  Adventure
# 524                            The Avengers   2012-05-04     Action
# 532                              Iron Man 3   2013-05-03     Action
# 539                                  Frozen   2013-11-22  Adventure
# 549                 Guardians of the Galaxy   2014-08-01  Adventure
# 558                 Avengers: Age of Ultron   2015-05-01     Action
# 560                              Inside Out   2015-06-19  Adventure
# 564    Star Wars Ep. VII: The Force Awakens   2015-12-18  Adventure
# 566                                Zootopia   2016-03-04  Adventure
# 567                         The Jungle Book   2016-04-15  Adventure
# 569              Captain America: Civil War   2016-05-06     Action
# 571                            Finding Dory   2016-06-17  Adventure
# 578            Rogue One: A Star Wars Story   2016-12-16  Adventure
#
#     mpaa_rating  total_gross  inflation_adjusted_gross
# 179           G    422780140                 761640898
# 384           G    380529370                 518148559
# 385       PG-13    305411224                 426967926
# 441       PG-13    423315812                 544817142
# 457       PG-13    309420425                 379129960
# 494          PG    334191110                 357063499
# 499           G    415004880                 443408255
# 524       PG-13    623279547                 660081224
# 532       PG-13    408992272                 424084233
# 539          PG    400738009                 414997174
# 549       PG-13    333172112                 343771168
# 558       PG-13    459005868                 459005868
# 560          PG    356461711                 356461711
# 564       PG-13    936662225                 936662225
# 566          PG    341268248                 341268248
# 567          PG    364001123                 364001123
# 569       PG-13    408084349                 408084349
# 571          PG    486295561                 486295561
# 578       PG-13    529483936                 529483936

# %%
#Group by genre and sum the total income of the movies
group_by_genre = moives.groupby("genre")["total_gross"].sum().reset_index()
group_by_genre
# Out:
#        genre  total_gross
# 0     Action   1899362036
# 1  Adventure   6338735886

# %%
#Plot a pie chart as per the genre and fetch which category of movie to make for making the maximum profit
value = group_by_genre["total_gross"]
label = group_by_genre["genre"]
plt.pie(value, labels=label, autopct="%0.2f%%", radius=2)
plt.show()

# %% [markdown]
# Conclusion :

# %%
print("Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion ")
# Out:
# Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion

# %%
print("Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion ")
# Out:
# Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion

# %%
print("Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion ")
# Out:
# Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion

# %%
print("Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion ")
# Out:
# Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion

# %%
print("Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion ")
# Out:
# Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion Conclusion
