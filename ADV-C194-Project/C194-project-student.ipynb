# %%
print("Name : ")
print("We will be cleaning the big data and make a comparison to show who has a healthier heart smokers OR non smokers, uisng a line graph")
print("Also we will be deriviring which age group has the high chances of coronary heart disease in 10 years")
# Out:
# Name :
# We will be cleaning the big data and make a comparison to show who has a healthier heart smokers OR non smokers, uisng a line graph
# Also we will be deriviring which age group has the high chances of coronary heart disease in 10 years

# %% [markdown]
# # Task 1 - Plot a line graph to show the difference between heart rate of smokers and non smokers

# %%
#Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#read the csv
df = pd.read_csv("framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
#Filter and make a new dataframe for non smokers
non_smoker = df.loc[df["currentSmoker"] == 0]
non_smoker
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 5        0   43        2.0              0         0.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# 8        1   52        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4226     1   58        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 5                   0             1         0    228.0  180.0  110.0  30.30
# 6                   0             0         0    205.0  138.0   71.0  33.11
# 8                   0             1         0    260.0  141.5   89.0  26.36
# ...               ...           ...       ...      ...    ...    ...    ...
# 4226                0             0         0    233.0  125.5   84.0  26.05
# 4228                0             1         1    260.0  190.0  130.0  43.67
# 4231                0             1         0    187.0  141.0   81.0  24.96
# 4232                0             1         0    176.0  168.0   97.0  23.14
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 5          77.0     99.0           0
# 6          60.0     85.0           1
# 8          76.0     79.0           0
# ...         ...      ...         ...
# 4226       67.0     76.0           1
# 4228       85.0    260.0           0
# 4231       80.0     81.0           0
# 4232       60.0     79.0           1
# 4237       80.0    107.0           0
#
# [2144 rows x 16 columns]

# %%
#Group by age column and find average heart rate at different age
age_heart = df.groupby("age")["heartRate"].mean().reset_index()
age_heart
# Out:
#     age  heartRate
# 0    32  80.000000
# 1    33  75.600000
# 2    34  73.555556
# 3    35  73.785714
# 4    36  74.761905
# 5    37  75.043478
# 6    38  76.631944
# 7    39  75.958580
# 8    40  76.518325
# 9    41  75.977011
# 10   42  75.522222
# 11   43  77.603774
# 12   44  74.867470
# 13   45  76.166667
# 14   46  78.027473
# 15   47  76.184397
# 16   48  76.028902
# 17   49  75.363636
# 18   50  76.457143
# 19   51  75.821918
# 20   52  76.255034
# 21   53  77.273381
# 22   54  75.598485
# 23   55  74.965517
# 24   56  73.902439
# 25   57  75.276423
# 26   58  76.675214
# 27   59  74.705882
# 28   60  76.099099
# 29   61  74.681818
# 30   62  74.454545
# 31   63  74.281818
# 32   64  76.706522
# 33   65  74.473684
# 34   66  78.868421
# 35   67  76.266667
# 36   68  80.277778
# 37   69  77.000000
# 38   70  64.000000

# %%
#Filter and make a new dataframe for smokers
smoker = df.loc[df["currentSmoker"] == 1]
smoker
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 7        0   45        2.0              1        20.0     0.0
# 9        1   43        1.0              1        30.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4230     0   56        1.0              1         3.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# 7                   0             0         0    313.0  100.0   71.0  21.68
# 9                   0             1         0    225.0  162.0  107.0  23.61
# ...               ...           ...       ...      ...    ...    ...    ...
# 4230                0             1         0    268.0  170.0  102.0  22.89
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
#
#       heartRate  glucose  TenYearCHD
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# 7          79.0     78.0           0
# 9          93.0     88.0           0
# ...         ...      ...         ...
# 4230       57.0      NaN           0
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
#
# [2094 rows x 16 columns]

# %%
#Group by age column and find average heart rate at different age
age_heart = df.groupby("age")["heartRate"].mean().reset_index()
age_heart
# Out:
#     age  heartRate
# 0    32  80.000000
# 1    33  75.600000
# 2    34  73.555556
# 3    35  73.785714
# 4    36  74.761905
# 5    37  75.043478
# 6    38  76.631944
# 7    39  75.958580
# 8    40  76.518325
# 9    41  75.977011
# 10   42  75.522222
# 11   43  77.603774
# 12   44  74.867470
# 13   45  76.166667
# 14   46  78.027473
# 15   47  76.184397
# 16   48  76.028902
# 17   49  75.363636
# 18   50  76.457143
# 19   51  75.821918
# 20   52  76.255034
# 21   53  77.273381
# 22   54  75.598485
# 23   55  74.965517
# 24   56  73.902439
# 25   57  75.276423
# 26   58  76.675214
# 27   59  74.705882
# 28   60  76.099099
# 29   61  74.681818
# 30   62  74.454545
# 31   63  74.281818
# 32   64  76.706522
# 33   65  74.473684
# 34   66  78.868421
# 35   67  76.266667
# 36   68  80.277778
# 37   69  77.000000
# 38   70  64.000000

# %% [markdown]
# Conslusion -

# %% [markdown]
# # Task 2 - Which age group have high chances of having coronary heart disease in 10 years

# %%
#Read the csv
csv = pd.read_csv("framingham.csv")
#Filter and make a new dataframe for those who has chances of having coronary heart disease in 10 years
filter_in_ten_yrs = csv.loc[csv["TenYearCHD"] == 1]
filter_in_ten_yrs
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3        0   61        3.0              1        30.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# 15       0   38        2.0              1        20.0     0.0
# 17       0   46        2.0              1        20.0     0.0
# 25       1   47        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4221     1   50        1.0              0         0.0     0.0
# 4223     1   56        4.0              0         0.0     1.0
# 4226     1   58        1.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 6                   0             0         0    205.0  138.0   71.0  33.11
# 15                  0             1         0    221.0  140.0   90.0  21.35
# 17                  0             0         0    291.0  112.0   78.0  23.38
# 25                  0             0         0    294.0  102.0   68.0  24.18
# ...               ...           ...       ...      ...    ...    ...    ...
# 4221                0             0         0    260.0  119.0   74.0  21.85
# 4223                0             1         0    287.0  149.0   98.0  21.68
# 4226                0             0         0    233.0  125.5   84.0  26.05
# 4232                0             1         0    176.0  168.0   97.0  23.14
# 4233                0             1         0    313.0  179.0   92.0  25.97
#
#       heartRate  glucose  TenYearCHD
# 3          65.0    103.0           1
# 6          60.0     85.0           1
# 15         95.0     70.0           1
# 17         80.0     89.0           1
# 25         62.0     66.0           1
# ...         ...      ...         ...
# 4221       80.0     72.0           1
# 4223       90.0     75.0           1
# 4226       67.0     76.0           1
# 4232       60.0     79.0           1
# 4233       66.0     86.0           1
#
# [644 rows x 16 columns]

# %%
#Group by age column and count the rows of TenYearCHD column
group_by_age_Ten_Year_CHD = csv.groupby("age")["TenYearCHD"].count().reset_index()
group_by_age_Ten_Year_CHD
# Out:
#     age  TenYearCHD
# 0    32           1
# 1    33           5
# 2    34          18
# 3    35          42
# 4    36          84
# 5    37          92
# 6    38         144
# 7    39         169
# 8    40         191
# 9    41         174
# 10   42         180
# 11   43         159
# 12   44         166
# 13   45         162
# 14   46         182
# 15   47         141
# 16   48         173
# 17   49         132
# 18   50         140
# 19   51         146
# 20   52         149
# 21   53         139
# 22   54         132
# 23   55         145
# 24   56         123
# 25   57         123
# 26   58         117
# 27   59         119
# 28   60         111
# 29   61         110
# 30   62          99
# 31   63         110
# 32   64          93
# 33   65          57
# 34   66          38
# 35   67          45
# 36   68          18
# 37   69           7
# 38   70           2

# %%
#Plot a line graph to show total number of people having a chance of coronary heart disease in 10 years
label = group_by_age_Ten_Year_CHD["age"]
value = group_by_age_Ten_Year_CHD["TenYearCHD"]

plt.subplots(figsize=(19,8))

plt.plot(label, value, label="Age group and their chance of coronary heart disease in 10 years", linewidth=3.0)

plt.xlabel("Age")
plt.xticks(rotation="vertical")
plt.ylabel("TenYearCHD")
plt.title("Age group and their chance of coronary heart disease in 10 years")
plt.legend()

# %% [markdown]
# Conslusion -
